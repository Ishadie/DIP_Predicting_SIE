# %%
pip install pytorch-lightning
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pytorch-lightning
#   Downloading pytorch_lightning-2.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: torch>=2.1.0 in /home/namir-i/.local/lib/python3.8/site-packages (from pytorch-lightning) (2.4.1+cu118)
# Requirement already satisfied: tqdm>=4.57.0 in /home/namir-i/.local/lib/python3.8/site-packages (from pytorch-lightning) (4.67.1)
# Collecting PyYAML>=5.4 (from pytorch-lightning)
#   Downloading PyYAML-6.0.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/lib/python3/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (2024.3.1)
# Collecting torchmetrics>=0.7.0 (from pytorch-lightning)
#   Downloading torchmetrics-1.5.2-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: packaging>=20.0 in /home/namir-i/.local/lib/python3.8/site-packages (from pytorch-lightning) (25.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.8/dist-packages (from pytorch-lightning) (4.12.2)
# Collecting lightning-utilities>=0.10.0 (from pytorch-lightning)
#   Downloading lightning_utilities-0.11.9-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/namir-i/.local/lib/python3.8/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (3.10.11)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from lightning-utilities>=0.10.0->pytorch-lightning) (45.2.0)
# Requirement already satisfied: filelock in /usr/lib/python3/dist-packages (from torch>=2.1.0->pytorch-lightning) (3.0.12)
# Requirement already satisfied: sympy in /home/namir-i/.local/lib/python3.8/site-packages (from torch>=2.1.0->pytorch-lightning) (1.13.3)
# Requirement already satisfied: networkx in /usr/lib/python3/dist-packages (from torch>=2.1.0->pytorch-lightning) (2.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from torch>=2.1.0->pytorch-lightning) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in /home/namir-i/.local/lib/python3.8/site-packages (from torch>=2.1.0->pytorch-lightning) (11.8.89)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in /home/namir-i/.local/lib/python3.8/site-packages (from torch>=2.1.0->pytorch-lightning) (11.8.89)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in /home/namir-i/.local/lib/python3.8/site-packages (from torch>=2.1.0->pytorch-lightning) (11.8.87)
# Requirement already satisfied: nvidia-cudnn-cu11==9.1.0.70 in /home/namir-i/.local/lib/python3.8/site-packages (from torch>=2.1.0->pytorch-lightning) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in /home/namir-i/.local/lib/python3.8/site-packages (from torch>=2.1.0->pytorch-lightning) (11.11.3.6)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/namir-i/.local/lib/python3.8/site-packages (from torch>=2.1.0->pytorch-lightning) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in /home/namir-i/.local/lib/python3.8/site-packages (from torch>=2.1.0->pytorch-lightning) (10.3.0.86)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in /home/namir-i/.local/lib/python3.8/site-packages (from torch>=2.1.0->pytorch-lightning) (11.4.1.48)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in /home/namir-i/.local/lib/python3.8/site-packages (from torch>=2.1.0->pytorch-lightning) (11.7.5.86)
# Requirement already satisfied: nvidia-nccl-cu11==2.20.5 in /home/namir-i/.local/lib/python3.8/site-packages (from torch>=2.1.0->pytorch-lightning) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in /home/namir-i/.local/lib/python3.8/site-packages (from torch>=2.1.0->pytorch-lightning) (11.8.86)
# Requirement already satisfied: triton==3.0.0 in /home/namir-i/.local/lib/python3.8/site-packages (from torch>=2.1.0->pytorch-lightning) (3.0.0)
# Requirement already satisfied: numpy>1.20.0 in /home/namir-i/.local/lib/python3.8/site-packages (from torchmetrics>=0.7.0->pytorch-lightning) (1.23.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/namir-i/.local/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/namir-i/.local/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/namir-i/.local/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/namir-i/.local/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /home/namir-i/.local/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.15.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/namir-i/.local/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from jinja2->torch>=2.1.0->pytorch-lightning) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/namir-i/.local/lib/python3.8/site-packages (from sympy->torch>=2.1.0->pytorch-lightning) (1.3.0)
# Requirement already satisfied: idna>=2.0 in /usr/lib/python3/dist-packages (from yarl<2.0,>=1.12.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (2.8)
# Requirement already satisfied: propcache>=0.2.0 in /home/namir-i/.local/lib/python3.8/site-packages (from yarl<2.0,>=1.12.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (0.2.0)
# Downloading pytorch_lightning-2.4.0-py3-none-any.whl (815 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.2/815.2 kB 11.8 MB/s eta 0:00:00
# Downloading lightning_utilities-0.11.9-py3-none-any.whl (28 kB)
# Downloading PyYAML-6.0.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (746 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 746.5/746.5 kB 49.8 MB/s eta 0:00:00
# Downloading torchmetrics-1.5.2-py3-none-any.whl (891 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 891.4/891.4 kB 70.7 MB/s eta 0:00:00
# Installing collected packages: PyYAML, lightning-utilities, torchmetrics, pytorch-lightning
# Successfully installed PyYAML-6.0.2 lightning-utilities-0.11.9 pytorch-lightning-2.4.0 torchmetrics-1.5.2
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pytesseract
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pytesseract
#   Downloading pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=21.3 in /home/namir-i/.local/lib/python3.8/site-packages (from pytesseract) (25.0)
# Requirement already satisfied: Pillow>=8.0.0 in /home/namir-i/.local/lib/python3.8/site-packages (from pytesseract) (10.4.0)
# Downloading pytesseract-0.3.13-py3-none-any.whl (14 kB)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.13
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install optuna
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting optuna
#   Downloading optuna-4.4.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.14.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /home/namir-i/.local/lib/python3.8/site-packages (from optuna) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /home/namir-i/.local/lib/python3.8/site-packages (from optuna) (25.0)
# Collecting sqlalchemy>=1.4.2 (from optuna)
#   Downloading sqlalchemy-2.0.41-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: tqdm in /home/namir-i/.local/lib/python3.8/site-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /home/namir-i/.local/lib/python3.8/site-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from alembic>=1.5.0->optuna) (8.5.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.8/dist-packages (from alembic>=1.5.0->optuna) (6.4.5)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.8/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Collecting greenlet>=1 (from sqlalchemy>=1.4.2->optuna)
#   Downloading greenlet-3.1.1-cp38-cp38-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata->alembic>=1.5.0->optuna) (3.20.2)
# Downloading optuna-4.4.0-py3-none-any.whl (395 kB)
# Downloading alembic-1.14.1-py3-none-any.whl (233 kB)
# Downloading sqlalchemy-2.0.41-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 44.8 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading greenlet-3.1.1-cp38-cp38-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (605 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 606.0/606.0 kB 49.1 MB/s eta 0:00:00
# Installing collected packages: greenlet, colorlog, sqlalchemy, alembic, optuna
# Successfully installed alembic-1.14.1 colorlog-6.9.0 greenlet-3.1.1 optuna-4.4.0 sqlalchemy-2.0.41
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting opencv-python
#   Downloading opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: numpy<2.0 in /home/namir-i/.local/lib/python3.8/site-packages (from opencv-python) (1.23.5)
# Downloading opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (67.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 59.2 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.12.0.88
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/namir-i/.local/lib/python3.8/site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=1.2 in /home/namir-i/.local/lib/python3.8/site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/namir-i/.local/lib/python3.8/site-packages (from seaborn) (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/namir-i/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/lib/python3/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/namir-i/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/lib/python3/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.0.1)
# Requirement already satisfied: packaging>=20.0 in /home/namir-i/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/namir-i/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.4.5)
# Requirement already satisfied: pytz>=2020.1 in /home/namir-i/.local/lib/python3.8/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/namir-i/.local/lib/python3.8/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.20.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.14.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import pytesseract
import matplotlib.pyplot as plt
import pandas as pd
import os
os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"
import torch

import torch
import random
from transformers import ViTFeatureExtractor, ViTModel
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset
import torch.nn as nn
import torch.optim as optim
from torch.nn import MultiheadAttention
from scipy.signal import savgol_filter
import matplotlib.pyplot as plt
import seaborn as sns
import pytorch_lightning as pl
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import itertools
import optuna
import json
from pytorch_lightning.callbacks import EarlyStopping
from sklearn.decomposition import PCA

# %% [markdown]
# #1. Multimodal Time Series Model using Transformer and GRU

# %%
import os
os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"
import torch
torch.use_deterministic_algorithms(False)

import json
import pandas as pd
import numpy as np

from torch import nn
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
import pytorch_lightning as pl
from pytorch_lightning.loggers import CSVLogger
from pytorch_lightning.callbacks import ModelCheckpoint
from torch.nn import TransformerEncoder, TransformerEncoderLayer
import optuna

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

csv_file_path = "/home/namir-i/sie/ice_extent_with_sst.csv" 
df = pd.read_csv(csv_file_path)
df = df.sort_values(["Year", "Image"])

# year ranges
train_years = (1980, 2014)
val_years   = (2015, 2019)
test_years  = (2020, 2024)

# Split by year
train_df = df[df["Year"].between(*train_years)]
val_df   = df[df["Year"].between(*val_years)]
test_df  = df[df["Year"].between(*test_years)]

numerical_features = ["Ice Coverage (%)", "Retreat Area (Since 1979) (%)","sst"]
vit_features       = [f"ViT_Feature_{i}" for i in range(768)]
target_column      = ["Retreat Area (Yearly) (%)"]

# Sequence creation
sequence_length = 3

def create_sequences(df, sequence_length, num_feats, vit_feats, tgt_col):
    seq_num, seq_vit, tgt, yrs = [], [], [], []
    for i in range(len(df) - sequence_length + 1):
        seq_num.append(df.iloc[i:i+sequence_length][num_feats].values)
        seq_vit.append(df.iloc[i:i+sequence_length][vit_feats].values)
        tgt.append(df.iloc[i+sequence_length-1][tgt_col].values)
        yrs.append(df.iloc[i+sequence_length-1]["Year"])
    return (np.array(seq_num),
            np.array(seq_vit),
            np.array(tgt).flatten(),
            np.array(yrs))

seq_num_train, seq_vit_train, y_train, years_train = create_sequences(
    train_df, sequence_length, numerical_features, vit_features, target_column
)
seq_num_val, seq_vit_val, y_val, years_val       = create_sequences(
    val_df, sequence_length, numerical_features, vit_features, target_column
)
seq_num_test, seq_vit_test, y_test, years_test    = create_sequences(
    test_df, sequence_length, numerical_features, vit_features, target_column
)

# Normalize Features & Targets

scaler_num    = StandardScaler()
scaler_target = StandardScaler()

flat_train_num = seq_num_train.reshape(-1, len(numerical_features))
scaler_num.fit(flat_train_num)
train_num = scaler_num.transform(flat_train_num).reshape(seq_num_train.shape)
val_num   = scaler_num.transform(seq_num_val.reshape(-1, len(numerical_features))).reshape(seq_num_val.shape)
test_num  = scaler_num.transform(seq_num_test.reshape(-1, len(numerical_features))).reshape(seq_num_test.shape)

y_train = scaler_target.fit_transform(y_train.reshape(-1,1)).flatten()
y_val   = scaler_target.transform(y_val.reshape(-1,1)).flatten()
y_test  = scaler_target.transform(y_test.reshape(-1,1)).flatten()

# PyTorch Tensors & DataLoaders

X_train_num = torch.tensor(train_num, dtype=torch.float32)
X_train_vit = torch.tensor(seq_vit_train, dtype=torch.float32)
y_train_t   = torch.tensor(y_train, dtype=torch.float32)

X_val_num   = torch.tensor(val_num, dtype=torch.float32)
X_val_vit   = torch.tensor(seq_vit_val, dtype=torch.float32)
y_val_t     = torch.tensor(y_val, dtype=torch.float32)

X_test_num  = torch.tensor(test_num, dtype=torch.float32)
X_test_vit  = torch.tensor(seq_vit_test, dtype=torch.float32)
y_test_t    = torch.tensor(y_test, dtype=torch.float32)

train_dataset = TensorDataset(X_train_num, X_train_vit, y_train_t)
val_dataset   = TensorDataset(X_val_num,   X_val_vit,   y_val_t)
test_dataset  = TensorDataset(X_test_num,  X_test_vit,  y_test_t)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True,  num_workers=2)
val_loader   = DataLoader(val_dataset,   batch_size=32, shuffle=False, num_workers=2)
test_loader  = DataLoader(test_dataset,  batch_size=32, shuffle=False, num_workers=2)

print(f"Train: {train_years} → {len(train_dataset)} sequences")
print(f"Val:   {val_years} → {len(val_dataset)} sequences")
print(f"Test:  {test_years} → {len(test_dataset)} sequences")

# Multimodal Transformer+GRU Model

class CombinedTransformerGRUModel(pl.LightningModule):
    def __init__(
        self,
        num_feature_dim,
        sequence_length: int = 3,
        d_model: int = 128,
        fusion_output_dim: int = 256,
        transformer_layers: int = 3,
        gru_hidden_size: int = 128,
        gru_layers: int = 1,
        dropout: float = 0.1,
        learning_rate: float = 1e-4,
    ):
        super().__init__()
        self.save_hyperparameters()

        self.encoder_num = nn.Linear(num_feature_dim, d_model)
        self.encoder_vit = nn.Linear(768, d_model)
        self.fusion_layer = nn.Linear(2 * d_model, fusion_output_dim)


        self.pos_emb = nn.Parameter(torch.zeros(1, sequence_length, fusion_output_dim))
        nn.init.trunc_normal_(self.pos_emb, std=0.02)

        # transformer & GRU
        encoder_layer = TransformerEncoderLayer(
            d_model=fusion_output_dim,
            nhead=8,
            dropout=dropout,
            batch_first=True
        )
        self.transformer = TransformerEncoder(encoder_layer, num_layers=transformer_layers)

        self.gru = nn.GRU(
            input_size=fusion_output_dim,
            hidden_size=gru_hidden_size,
            num_layers=gru_layers,
            batch_first=True,
            dropout=dropout if gru_layers > 1 else 0
        )

        self.attention = MultiheadAttention(
            embed_dim=gru_hidden_size,
            num_heads=1,
            batch_first=True
        )


        self.output_layer = nn.Linear(gru_hidden_size, 1)
        self.criterion = nn.MSELoss()
        self.learning_rate = learning_rate

    def forward(self, x_num, x_vit):
        # encode
        xn = self.encoder_num(x_num)
        xv = self.encoder_vit(x_vit)

        fused = self.fusion_layer(torch.cat([xn, xv], dim=2))

        fused = fused + self.pos_emb

        # transformer → GRU
        trans, _ = self.transformer(fused), None
        gru_out, _ = self.gru(trans)  # [B, Seq_len, Hidden]
        attn_output, _ = self.attention(gru_out, gru_out, gru_out)  # Self-attention
        attn_pooled = attn_output.mean(dim=1)  
        return self.output_layer(attn_pooled).squeeze()

        # _, h_n = self.gru(trans)
        # return self.output_layer(h_n[-1]).squeeze()


    def training_step(self, batch, batch_idx):
        x_num, x_vit, y = batch
        y_hat = self(x_num, x_vit)
        loss = self.criterion(y_hat, y)
        self.log("train_loss", loss, prog_bar=True, on_epoch=True)
        return loss

    def validation_step(self, batch, batch_idx):
        x_num, x_vit, y = batch
        y_hat = self(x_num, x_vit)
        loss = self.criterion(y_hat, y)
        self.log("val_loss", loss, prog_bar=True, on_epoch=True)
        return loss

    def configure_optimizers(self):
        opt = torch.optim.AdamW(self.parameters(), lr=self.learning_rate)
        sched = torch.optim.lr_scheduler.ReduceLROnPlateau(opt, mode="min", patience=3, factor=0.5)
        return {"optimizer": opt, "lr_scheduler": sched, "monitor": "val_loss"}


# Hyperparameter Tuning with Optuna

def objective(trial):
    params = {
        "d_model": trial.suggest_categorical("d_model", [64,128,256]),
        "fusion_output_dim": trial.suggest_categorical("fusion_output_dim", [128,256,512]),
        "gru_hidden_size": trial.suggest_categorical("gru_hidden_size", [64,128]),
        "dropout": trial.suggest_float("dropout", 0.1, 0.5),
        "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-3),
        "transformer_layers": trial.suggest_int("transformer_layers", 1, 6),
    }
    model = CombinedTransformerGRUModel(
        num_feature_dim=len(numerical_features),
        **params
    )
    logger = CSVLogger(save_dir="logs", name=f"trial_{trial.number}")
    ckpt  = ModelCheckpoint(monitor="val_loss", mode="min", save_top_k=1)
    trainer = pl.Trainer(
        max_epochs=50, logger=logger, callbacks=[ckpt],
        accelerator="gpu" if torch.cuda.is_available() else "cpu",
        devices=1, enable_progress_bar=False
    )
    trainer.fit(model, train_dataloaders=train_loader, val_dataloaders=val_loader)
    return ckpt.best_model_score.item() if ckpt.best_model_score is not None else float("inf")

study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=50)
best_params = study.best_params
with open("/home/namir-i/sie/best_param/best_params.json", "w") as f:
    json.dump(best_params, f)


# Final Model Training & Evaluation

best = json.load(open("/home/namir-i/sie/best_param/best_params.json"))
final_model = CombinedTransformerGRUModel(
    num_feature_dim=len(numerical_features),
    **best
).to(device)

logger_final = CSVLogger(save_dir="/home/namir-i/sie/log", name="final_model")
ckpt_final  = ModelCheckpoint(monitor="val_loss", mode="min", save_top_k=1)
trainer = pl.Trainer(
    max_epochs=50, logger=logger_final, callbacks=[ckpt_final],
    accelerator="gpu" if torch.cuda.is_available() else "cpu", devices=1
)
trainer.fit(final_model, train_dataloaders=train_loader, val_dataloaders=val_loader)

def evaluate_model(model, loader, device="cpu"):
    model.to(device)
    model.eval()
    y_true, y_pred = [], []
    with torch.no_grad():
        for x_num, x_vit, y in loader:
            x_num, x_vit = x_num.to(device), x_vit.to(device)
            y_hat = model(x_num, x_vit).cpu().numpy()
            y_true.extend(y.numpy())
            y_pred.extend(y_hat)
    return np.array(y_true), np.array(y_pred)

device = "cuda" if torch.cuda.is_available() else "cpu"

y_t, y_p = evaluate_model(final_model, test_loader, device)


from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
print("\n** Model Evaluation **")
print(f"MAE: {mean_absolute_error(y_t,y_p):.4f}, MSE: {mean_squared_error(y_t,y_p):.4f}, RMSE: {np.sqrt(mean_squared_error(y_t,y_p)):.4f}, R²: {r2_score(y_t,y_p):.4f}")

def predict_and_save_test_results(model, loader, scaler, years, path):
    y_true, y_pred = evaluate_model(model, loader, device)
    y_true_orig = scaler.inverse_transform(y_true.reshape(-1,1)).flatten()
    y_pred_orig = scaler.inverse_transform(y_pred.reshape(-1,1)).flatten()
    df_out = pd.DataFrame({
        "Year": years,
        "Actual Retreat Area (Yearly) (%)": y_true_orig,
        "Predicted Retreat Area (Yearly) (%)": y_pred_orig
    })
    df_out.groupby("Year", as_index=False).mean().to_csv(path, index=False)
    print("Saved to", path)
    return df_out

TEST_RESULTS_PATH = "/home/namir-i/sie/multimodal_sea_ice_extent_predictions.csv"
results_df = predict_and_save_test_results(final_model, test_loader, scaler_target, years_test, TEST_RESULTS_PATH)
# Out:
# [I 2025-07-28 00:02:32,059] A new study created in memory with name: no-name-72ed9e3a-1d51-4c9c-a055-4745be19e487
# /tmp/ipykernel_126469/2541209458.py:208: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-3),
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name         | Type               | Params | Mode
# ------------------------------------------------------------
# 0 | encoder_num  | Linear             | 256    | train
# 1 | encoder_vit  | Linear             | 49.2 K | train
# 2 | fusion_layer | Linear             | 16.5 K | train
# 3 | transformer  | TransformerEncoder | 2.4 M  | train
# 4 | gru          | GRU                | 99.1 K | train
# 5 | attention    | MultiheadAttention | 66.0 K | train
# 6 | output_layer | Linear             | 129    | train
# 7 | criterion    | MSELoss            | 0      | train
#   | other params | n/a                | 384    | n/a
# ------------------------------------------------------------
# 2.6 M     Trainable params
# 0         Non-trainable params
# 2.6 M     Total params
# 10.415    Total estimated model params size (MB)
# 50        Modules in train mode
# 0         Modules in eval mode
# Train: (1980, 2014) → 990 sequences
# Val:   (2015, 2019) → 158 sequences
# Test:  (2020, 2024) → 158 sequences
# /home/namir-i/.local/lib/python3.8/site-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (31) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2025-07-28 00:03:28,552] Trial 0 finished with value: 0.11050410568714142 and parameters: {'d_model': 64, 'fusion_output_dim': 128, 'gru_hidden_size': 128, 'dropout': 0.4063140898979093, 'learning_rate': 0.0001481769798518655, 'transformer_layers': 4}. Best is trial 0 with value: 0.11050410568714142.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name         | Type               | Params | Mode
# ------------------------------------------------------------
# 0 | encoder_num  | Linear             | 256    | train
# 1 | encoder_vit  | Linear             | 49.2 K | train
# 2 | fusion_layer | Linear             | 33.0 K | train
# 3 | transformer  | TransformerEncoder | 2.6 M  | train
# 4 | gru          | GRU                | 148 K  | train
# 5 | attention    | MultiheadAttention | 66.0 K | train
# 6 | output_layer | Linear             | 129    | train
# 7 | criterion    | MSELoss            | 0      | train
#   | other params | n/a                | 768    | n/a
# ------------------------------------------------------------
# 2.9 M     Trainable params
# 0         Non-trainable params
# 2.9 M     Total params
# 11.711    Total estimated model params size (MB)
# 30        Modules in train mode
# 0         Modules in eval mode
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2025-07-28 00:04:14,693] Trial 1 finished with value: 0.104519322514534 and parameters: {'d_model': 64, 'fusion_output_dim': 256, 'gru_hidden_size': 128, 'dropout': 0.4683435579791203, 'learning_rate': 0.0003606671611636613, 'transformer_layers': 2}. Best is trial 1 with value: 0.104519322514534.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name         | Type               | Params | Mode
# ------------------------------------------------------------
# 0 | encoder_num  | Linear             | 512    | train
# 1 | encoder_vit  | Linear             | 98.4 K | train
# 2 | fusion_layer | Linear             | 65.8 K | train
# 3 | transformer  | TransformerEncoder | 5.3 M  | train
# 4 | gru          | GRU                | 61.8 K | train
# 5 | attention    | MultiheadAttention | 16.6 K | train
# 6 | output_layer | Linear             | 65     | train
# 7 | criterion    | MSELoss            | 0      | train
#   | other params | n/a                | 768    | n/a
# ------------------------------------------------------------
# 5.5 M     Trainable params
# 0         Non-trainable params
# 5.5 M     Total params
# 22.017    Total estimated model params size (MB)
# 50        Modules in train mode
# 0         Modules in eval mode
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2025-07-28 00:05:11,910] Trial 2 finished with value: 0.11817829310894012 and parameters: {'d_model': 128, 'fusion_output_dim': 256, 'gru_hidden_size': 64, 'dropout': 0.17415065836301308, 'learning_rate': 0.00012366961082253442, 'transformer_layers': 4}. Best is trial 1 with value: 0.104519322514534.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name         | Type               | Params | Mode
# ------------------------------------------------------------
# 0 | encoder_num  | Linear             | 1.0 K  | train
# 1 | encoder_vit  | Linear             | 196 K  | train
# 2 | fusion_layer | Linear             | 262 K  | train
# 3 | transformer  | TransformerEncoder | 15.8 M | train
# 4 | gru          | GRU                | 246 K  | train
# 5 | attention    | MultiheadAttention | 66.0 K | train
# 6 | output_layer | Linear             | 129    | train
# 7 | criterion    | MSELoss            | 0      | train
#   | other params | n/a                | 1.5 K  | n/a
# ------------------------------------------------------------
# 16.5 M    Trainable params
# 0         Non-trainable params
# 16.5 M    Total params
# 66.147    Total estimated model params size (MB)
# 60        Modules in train mode
# 0         Modules in eval mode
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2025-07-28 00:06:17,986] Trial 3 finished with value: 0.1128474697470665 and parameters: {'d_model': 256, 'fusion_output_dim': 512, 'gru_hidden_size': 128, 'dropout': 0.18589952326774684, 'learning_rate': 0.00010097634743962574, 'transformer_layers': 5}. Best is trial 1 with value: 0.104519322514534.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name         | Type               | Params | Mode
# ------------------------------------------------------------
# 0 | encoder_num  | Linear             | 256    | train
# 1 | encoder_vit  | Linear             | 49.2 K | train
# 2 | fusion_layer | Linear             | 33.0 K | train
# 3 | transformer  | TransformerEncoder | 1.3 M  | train
# 4 | gru          | GRU                | 61.8 K | train
# 5 | attention    | MultiheadAttention | 16.6 K | train
# 6 | output_layer | Linear             | 65     | train
# 7 | criterion    | MSELoss            | 0      | train
#   | other params | n/a                | 768    | n/a
# ------------------------------------------------------------
# 1.5 M     Trainable params
# 0         Non-trainable params
# 1.5 M     Total params
# 5.907     Total estimated model params size (MB)
# 20        Modules in train mode
# 0         Modules in eval mode
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2025-07-28 00:06:56,689] Trial 4 finished with value: 0.08651210367679596 and parameters: {'d_model': 64, 'fusion_output_dim': 256, 'gru_hidden_size': 64, 'dropout': 0.49440621744670055, 'learning_rate': 0.0005676715300586955, 'transformer_layers': 1}. Best is trial 4 with value: 0.08651210367679596.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name         | Type               | Params | Mode
# ------------------------------------------------------------
# 0 | encoder_num  | Linear             | 512    | train
# 1 | encoder_vit  | Linear             | 98.4 K | train
# 2 | fusion_layer | Linear             | 65.8 K | train
# 3 | transformer  | TransformerEncoder | 6.6 M  | train
# 4 | gru          | GRU                | 61.8 K | train
# 5 | attention    | MultiheadAttention | 16.6 K | train
# 6 | output_layer | Linear             | 65     | train
# 7 | criterion    | MSELoss            | 0      | train
#   | other params | n/a                | 768    | n/a
# ------------------------------------------------------------
# 6.8 M     Trainable params
# 0         Non-trainable params
# 6.8 M     Total params
# 27.278    Total estimated model params size (MB)
# 60        Modules in train mode
# 0         Modules in eval mode
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2025-07-28 00:07:59,708] Trial 5 finished with value: 0.7515872120857239 and parameters: {'d_model': 128, 'fusion_output_dim': 256, 'gru_hidden_size': 64, 'dropout': 0.38020014120522216, 'learning_rate': 0.0005713998471815668, 'transformer_layers': 5}. Best is trial 4 with value: 0.08651210367679596.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name         | Type               | Params | Mode
# ------------------------------------------------------------
# 0 | encoder_num  | Linear             | 512    | train
# 1 | encoder_vit  | Linear             | 98.4 K | train
# 2 | fusion_layer | Linear             | 65.8 K | train
# 3 | transformer  | TransformerEncoder | 2.6 M  | train
# 4 | gru          | GRU                | 148 K  | train
# 5 | attention    | MultiheadAttention | 66.0 K | train
# 6 | output_layer | Linear             | 129    | train
# 7 | criterion    | MSELoss            | 0      | train
#   | other params | n/a                | 768    | n/a
# ------------------------------------------------------------
# 3.0 M     Trainable params
# 0         Non-trainable params
# 3.0 M     Total params
# 12.040    Total estimated model params size (MB)
# 30        Modules in train mode
# 0         Modules in eval mode
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2025-07-28 00:08:48,919] Trial 6 finished with value: 0.1034485399723053 and parameters: {'d_model': 128, 'fusion_output_dim': 256, 'gru_hidden_size': 128, 'dropout': 0.11981776734503101, 'learning_rate': 0.00017518967401179735, 'transformer_layers': 2}. Best is trial 4 with value: 0.08651210367679596.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name         | Type               | Params | Mode
# ------------------------------------------------------------
# 0 | encoder_num  | Linear             | 512    | train
# 1 | encoder_vit  | Linear             | 98.4 K | train
# 2 | fusion_layer | Linear             | 65.8 K | train
# 3 | transformer  | TransformerEncoder | 3.9 M  | train
# 4 | gru          | GRU                | 61.8 K | train
# 5 | attention    | MultiheadAttention | 16.6 K | train
# 6 | output_layer | Linear             | 65     | train
# 7 | criterion    | MSELoss            | 0      | train
#   | other params | n/a                | 768    | n/a
# ------------------------------------------------------------
# 4.2 M     Trainable params
# 0         Non-trainable params
# 4.2 M     Total params
# 16.757    Total estimated model params size (MB)
# 40        Modules in train mode
# 0         Modules in eval mode
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2025-07-28 00:09:44,194] Trial 7 finished with value: 0.38696232438087463 and parameters: {'d_model': 128, 'fusion_output_dim': 256, 'gru_hidden_size': 64, 'dropout': 0.4395639435961316, 'learning_rate': 0.0008935665728615722, 'transformer_layers': 3}. Best is trial 4 with value: 0.08651210367679596.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name         | Type               | Params | Mode
# ------------------------------------------------------------
# 0 | encoder_num  | Linear             | 512    | train
# 1 | encoder_vit  | Linear             | 98.4 K | train
# 2 | fusion_layer | Linear             | 65.8 K | train
# 3 | transformer  | TransformerEncoder | 5.3 M  | train
# 4 | gru          | GRU                | 61.8 K | train
# 5 | attention    | MultiheadAttention | 16.6 K | train
# 6 | output_layer | Linear             | 65     | train
# 7 | criterion    | MSELoss            | 0      | train
#   | other params | n/a                | 768    | n/a
# ------------------------------------------------------------
# 5.5 M     Trainable params
# 0         Non-trainable params
# 5.5 M     Total params
# 22.017    Total estimated model params size (MB)
# 50        Modules in train mode
# 0         Modules in eval mode
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2025-07-28 00:10:43,291] Trial 8 finished with value: 0.9978204369544983 and parameters: {'d_model': 128, 'fusion_output_dim': 256, 'gru_hidden_size': 64, 'dropout': 0.23506729648510163, 'learning_rate': 0.0009642634254876947, 'transformer_layers': 4}. Best is trial 4 with value: 0.08651210367679596.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name         | Type               | Params | Mode
# ------------------------------------------------------------
# 0 | encoder_num  | Linear             | 1.0 K  | train
# 1 | encoder_vit  | Linear             | 196 K  | train
# 2 | fusion_layer | Linear             | 262 K  | train
# 3 | transformer  | TransformerEncoder | 18.9 M | train
# 4 | gru          | GRU                | 246 K  | train
# 5 | attention    | MultiheadAttention | 66.0 K | train
# 6 | output_layer | Linear             | 129    | train
# 7 | criterion    | MSELoss            | 0      | train
#   | other params | n/a                | 1.5 K  | n/a
# ------------------------------------------------------------
# 19.7 M    Trainable params
# 0         Non-trainable params
# 19.7 M    Total params
# 78.756    Total estimated model params size (MB)
# 70        Modules in train mode
# 0         Modules in eval mode
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2025-07-28 00:11:55,392] Trial 9 finished with value: 1.1878126859664917 and parameters: {'d_model': 256, 'fusion_output_dim': 512, 'gru_hidden_size': 128, 'dropout': 0.2702284282528219, 'learning_rate': 0.000429621176386605, 'transformer_layers': 6}. Best is trial 4 with value: 0.08651210367679596.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name         | Type               | Params | Mode
# ------------------------------------------------------------
# 0 | encoder_num  | Linear             | 256    | train
# 1 | encoder_vit  | Linear             | 49.2 K | train
# 2 | fusion_layer | Linear             | 16.5 K | train
# 3 | transformer  | TransformerEncoder | 593 K  | train
# 4 | gru          | GRU                | 37.2 K | train
# 5 | attention    | MultiheadAttention | 16.6 K | train
# 6 | output_layer | Linear             | 65     | train
# 7 | criterion    | MSELoss            | 0      | train
#   | other params | n/a                | 384    | n/a
# ------------------------------------------------------------
# 713 K     Trainable params
# 0         Non-trainable params
# 713 K     Total params
# 2.853     Total estimated model params size (MB)
# 20        Modules in train mode
# 0         Modules in eval mode
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2025-07-28 00:12:35,651] Trial 10 finished with value: 0.10496392101049423 and parameters: {'d_model': 64, 'fusion_output_dim': 128, 'gru_hidden_size': 64, 'dropout': 0.3429713032628898, 'learning_rate': 0.0002650637328340102, 'transformer_layers': 1}. Best is trial 4 with value: 0.08651210367679596.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name         | Type               | Params | Mode
# ------------------------------------------------------------
# 0 | encoder_num  | Linear             | 256    | train
# 1 | encoder_vit  | Linear             | 49.2 K | train
# 2 | fusion_layer | Linear             | 33.0 K | train
# 3 | transformer  | TransformerEncoder | 1.3 M  | train
# 4 | gru          | GRU                | 148 K  | train
# 5 | attention    | MultiheadAttention | 66.0 K | train
# 6 | output_layer | Linear             | 129    | train
# 7 | criterion    | MSELoss            | 0      | train
#   | other params | n/a                | 768    | n/a
# ------------------------------------------------------------
# 1.6 M     Trainable params
# 0         Non-trainable params
# 1.6 M     Total params
# 6.451     Total estimated model params size (MB)
# 20        Modules in train mode
# 0         Modules in eval mode
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2025-07-28 00:13:16,413] Trial 11 finished with value: 0.1067807525396347 and parameters: {'d_model': 64, 'fusion_output_dim': 256, 'gru_hidden_size': 128, 'dropout': 0.11493024568995215, 'learning_rate': 0.0002144320207030981, 'transformer_layers': 1}. Best is trial 4 with value: 0.08651210367679596.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name         | Type               | Params | Mode
# ------------------------------------------------------------
# 0 | encoder_num  | Linear             | 512    | train
# 1 | encoder_vit  | Linear             | 98.4 K | train
# 2 | fusion_layer | Linear             | 65.8 K | train
# 3 | transformer  | TransformerEncoder | 2.6 M  | train
# 4 | gru          | GRU                | 148 K  | train
# 5 | attention    | MultiheadAttention | 66.0 K | train
# 6 | output_layer | Linear             | 129    | train
# 7 | criterion    | MSELoss            | 0      | train
#   | other params | n/a                | 768    | n/a
# ------------------------------------------------------------
# 3.0 M     Trainable params
# 0         Non-trainable params
# 3.0 M     Total params
# 12.040    Total estimated model params size (MB)
# 30        Modules in train mode
# 0         Modules in eval mode
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2025-07-28 00:14:06,580] Trial 12 finished with value: 0.10013461858034134 and parameters: {'d_model': 128, 'fusion_output_dim': 256, 'gru_hidden_size': 128, 'dropout': 0.31114476752232073, 'learning_rate': 0.00019827621895210953, 'transformer_layers': 2}. Best is trial 4 with value: 0.08651210367679596.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name         | Type               | Params | Mode
# ------------------------------------------------------------
# 0 | encoder_num  | Linear             | 256    | train
# 1 | encoder_vit  | Linear             | 49.2 K | train
# 2 | fusion_layer | Linear             | 66.0 K | train
# 3 | transformer  | TransformerEncoder | 6.3 M  | train
# 4 | gru          | GRU                | 110 K  | train
# 5 | attention    | MultiheadAttention | 16.6 K | train
# 6 | output_layer | Linear             | 65     | train
# 7 | criterion    | MSELoss            | 0      | train
#   | other params | n/a                | 1.5 K  | n/a
# ------------------------------------------------------------
# 6.5 M     Trainable params
# 0         Non-trainable params
# 6.5 M     Total params
# 26.198    Total estimated model params size (MB)
# 30        Modules in train mode
# 0         Modules in eval mode
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2025-07-28 00:15:00,609] Trial 13 finished with value: 0.09663023054599762 and parameters: {'d_model': 64, 'fusion_output_dim': 512, 'gru_hidden_size': 64, 'dropout': 0.49486603915016203, 'learning_rate': 0.0005806609383518891, 'transformer_layers': 2}. Best is trial 4 with value: 0.08651210367679596.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name         | Type               | Params | Mode
# ------------------------------------------------------------
# 0 | encoder_num  | Linear             | 256    | train
# 1 | encoder_vit  | Linear             | 49.2 K | train
# 2 | fusion_layer | Linear             | 66.0 K | train
# 3 | transformer  | TransformerEncoder | 3.2 M  | train
# 4 | gru          | GRU                | 110 K  | train
# 5 | attention    | MultiheadAttention | 16.6 K | train
# 6 | output_layer | Linear             | 65     | train
# 7 | criterion    | MSELoss            | 0      | train
#   | other params | n/a                | 1.5 K  | n/a
# ------------------------------------------------------------
# 3.4 M     Trainable params
# 0         Non-trainable params
# 3.4 M     Total params
# 13.588    Total estimated model params size (MB)
# 20        Modules in train mode
# 0         Modules in eval mode
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2025-07-28 00:15:42,694] Trial 14 finished with value: 0.10382498800754547 and parameters: {'d_model': 64, 'fusion_output_dim': 512, 'gru_hidden_size': 64, 'dropout': 0.49593969686825273, 'learning_rate': 0.0005832864142143325, 'transformer_layers': 1}. Best is trial 4 with value: 0.08651210367679596.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name         | Type               | Params | Mode
# ------------------------------------------------------------
# 0 | encoder_num  | Linear             | 256    | train
# 1 | encoder_vit  | Linear             | 49.2 K | train
# 2 | fusion_layer | Linear             | 66.0 K | train
# 3 | transformer  | TransformerEncoder | 9.5 M  | train
# 4 | gru          | GRU                | 110 K  | train
# 5 | attention    | MultiheadAttention | 16.6 K | train
# 6 | output_layer | Linear             | 65     | train
# 7 | criterion    | MSELoss            | 0      | train
#   | other params | n/a                | 1.5 K  | n/a
# ------------------------------------------------------------
# 9.7 M     Trainable params
# 0         Non-trainable params
# 9.7 M     Total params
# 38.808    Total estimated model params size (MB)
# 40        Modules in train mode
# 0         Modules in eval mode
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2025-07-28 00:16:39,301] Trial 15 finished with value: 0.7027268409729004 and parameters: {'d_model': 64, 'fusion_output_dim': 512, 'gru_hidden_size': 64, 'dropout': 0.49906968999247847, 'learning_rate': 0.0006305741605492209, 'transformer_layers': 3}. Best is trial 4 with value: 0.08651210367679596.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name         | Type               | Params | Mode
# ------------------------------------------------------------
# 0 | encoder_num  | Linear             | 256    | train
# 1 | encoder_vit  | Linear             | 49.2 K | train
# 2 | fusion_layer | Linear             | 66.0 K | train
# 3 | transformer  | TransformerEncoder | 6.3 M  | train
# 4 | gru          | GRU                | 110 K  | train
# 5 | attention    | MultiheadAttention | 16.6 K | train
# 6 | output_layer | Linear             | 65     | train
# 7 | criterion    | MSELoss            | 0      | train
#   | other params | n/a                | 1.5 K  | n/a
# ------------------------------------------------------------
# 6.5 M     Trainable params
# 0         Non-trainable params
# 6.5 M     Total params
# 26.198    Total estimated model params size (MB)
# 30        Modules in train mode
# 0         Modules in eval mode
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2025-07-28 00:17:32,446] Trial 16 finished with value: 0.10159255564212799 and parameters: {'d_model': 64, 'fusion_output_dim': 512, 'gru_hidden_size': 64, 'dropout': 0.4233888473840235, 'learning_rate': 0.0004473385206342524, 'transformer_layers': 2}. Best is trial 4 with value: 0.08651210367679596.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name         | Type               | Params | Mode
# ------------------------------------------------------------
# 0 | encoder_num  | Linear             | 256    | train
# 1 | encoder_vit  | Linear             | 49.2 K | train
# 2 | fusion_layer | Linear             | 16.5 K | train
# 3 | transformer  | TransformerEncoder | 593 K  | train
# 4 | gru          | GRU                | 37.2 K | train
# 5 | attention    | MultiheadAttention | 16.6 K | train
# 6 | output_layer | Linear             | 65     | train
# 7 | criterion    | MSELoss            | 0      | train
#   | other params | n/a                | 384    | n/a
# ------------------------------------------------------------
# 713 K     Trainable params
# 0         Non-trainable params
# 713 K     Total params
# 2.853     Total estimated model params size (MB)
# 20        Modules in train mode
# 0         Modules in eval mode
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2025-07-28 00:18:13,070] Trial 17 finished with value: 0.10123202949762344 and parameters: {'d_model': 64, 'fusion_output_dim': 128, 'gru_hidden_size': 64, 'dropout': 0.3670662850157281, 'learning_rate': 0.0007168040800644329, 'transformer_layers': 1}. Best is trial 4 with value: 0.08651210367679596.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name         | Type               | Params | Mode
# ------------------------------------------------------------
# 0 | encoder_num  | Linear             | 1.0 K  | train
# 1 | encoder_vit  | Linear             | 196 K  | train
# 2 | fusion_layer | Linear             | 262 K  | train
# 3 | transformer  | TransformerEncoder | 9.5 M  | train
# 4 | gru          | GRU                | 110 K  | train
# 5 | attention    | MultiheadAttention | 16.6 K | train
# 6 | output_layer | Linear             | 65     | train
# 7 | criterion    | MSELoss            | 0      | train
#   | other params | n/a                | 1.5 K  | n/a
# ------------------------------------------------------------
# 10.0 M    Trainable params
# 0         Non-trainable params
# 10.0 M    Total params
# 40.188    Total estimated model params size (MB)
# 40        Modules in train mode
# 0         Modules in eval mode
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2025-07-28 00:19:16,907] Trial 18 finished with value: 0.11772646009922028 and parameters: {'d_model': 256, 'fusion_output_dim': 512, 'gru_hidden_size': 64, 'dropout': 0.45267882598445797, 'learning_rate': 0.0003181781691497879, 'transformer_layers': 3}. Best is trial 4 with value: 0.08651210367679596.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name         | Type               | Params | Mode
# ------------------------------------------------------------
# 0 | encoder_num  | Linear             | 256    | train
# 1 | encoder_vit  | Linear             | 49.2 K | train
# 2 | fusion_layer | Linear             | 66.0 K | train
# 3 | transformer  | TransformerEncoder | 6.3 M  | train
# 4 | gru          | GRU                | 110 K  | train
# 5 | attention    | MultiheadAttention | 16.6 K | train
# 6 | output_layer | Linear             | 65     | train
# 7 | criterion    | MSELoss            | 0      | train
#   | other params | n/a                | 1.5 K  | n/a
# ------------------------------------------------------------
# 6.5 M     Trainable params
# 0         Non-trainable params
# 6.5 M     Total params
# 26.198    Total estimated model params size (MB)
# 30        Modules in train mode
# 0         Modules in eval mode
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2025-07-28 00:20:10,899] Trial 19 finished with value: 0.09438592195510864 and parameters: {'d_model': 64, 'fusion_output_dim': 512, 'gru_hidden_size': 64, 'dropout': 0.3952300765794163, 'learning_rate': 0.00045539714119656395, 'transformer_layers': 2}. Best is trial 4 with value: 0.08651210367679596.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name         | Type               | Params | Mode
# ------------------------------------------------------------
# 0 | encoder_num  | Linear             | 256    | train
# 1 | encoder_vit  | Linear             | 49.2 K | train
# 2 | fusion_layer | Linear             | 33.0 K | train
# 3 | transformer  | TransformerEncoder | 1.3 M  | train
# 4 | gru          | GRU                | 61.8 K | train
# 5 | attention    | MultiheadAttention | 16.6 K | train
# 6 | output_layer | Linear             | 65     | train
# 7 | criterion    | MSELoss            | 0      | train
#   | other params | n/a                | 768    | n/a
# ------------------------------------------------------------
# 1.5 M     Trainable params
# 0         Non-trainable params
# 1.5 M     Total params
# 5.907     Total estimated model params size (MB)
# 20        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |                                                                                | 0/? [00:00…
# Training: |                                                                                       | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# Validation: |                                                                                     | 0/? [00:00…
# `Trainer.fit` stopped: `max_epochs=50` reached.
# ** Model Evaluation **
# MAE: 0.1362, RMSE: 0.1637, R²: 0.9202
# Saved to /home/namir-i/sie/multimodal_sea_ice_extent_predictions.csv

# %% [markdown]
# #2. Epoch vs Validation Loss

# %%
import pandas as pd
import matplotlib.pyplot as plt

csv_path = r"/home/namir-i/sie/log/final_model/version_21/metrics.csv" #file path derived from log during testing
df = pd.read_csv(csv_path)

df_val = df.dropna(subset=["val_loss"])

epoch_loss = df_val.groupby("epoch")["val_loss"].last().reset_index()

plt.figure(figsize=(8, 6))
plt.plot(epoch_loss["epoch"], epoch_loss["val_loss"], marker='o', linestyle='-', color='blue')
plt.xlabel("Epoch", fontsize=12)
plt.ylabel("Validation Loss", fontsize=12)
plt.title("Epoch vs. Validation Loss", fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# #3. Comparison of Actual vs. Predicted Retreat Area Over Years

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

csv_path = r"/home/namir-i/sie/multimodal_sea_ice_extent_predictions.csv" #file path derived from log during testing
df = pd.read_csv(csv_path)
print(df)

years = df["Year"].astype(int)
actual_values = df["Actual Retreat Area (Yearly) (%)"]
predicted_values = df["Predicted Retreat Area (Yearly) (%)"]

x = np.arange(len(years))
width = 0.35

fig, ax = plt.subplots(figsize=(8, 6))

rects1 = ax.bar(x - width/2, actual_values, width, label='Actual', color='skyblue', edgecolor='black')

rects2 = ax.bar(x + width/2, predicted_values, width, label='Predicted', color='salmon', edgecolor='black')

ax.set_xlabel('Year', fontsize=12)
ax.set_ylabel('Retreat Area (Yearly) (%)', fontsize=12)
ax.set_title('Actual vs. Predicted Retreat Area by Year', fontsize=14)
ax.set_xticks(x)
ax.set_xticklabels(years, fontsize=12)
ax.legend(fontsize=12)
ax.grid(axis='y', linestyle='--', alpha=0.7)

for rect in rects1 + rects2:
    height = rect.get_height()
    ax.annotate(f'{height:.2f}',
                xy=(rect.get_x() + rect.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

plt.tight_layout()
plt.show()
# Out:
#    Year  Actual Retreat Area (Yearly) (%)  Predicted Retreat Area (Yearly) (%)
# 0  2020                              5.03                             5.110000
# 1  2021                              4.53                             4.470000
# 2  2022                              5.31                             5.680588
# 3  2023                              8.27                             7.950000
# 4  2024                              5.68                             5.490000
